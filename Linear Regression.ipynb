# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt

# %%
###Reading car Data
data=pd.read_csv('turboaz.csv',usecols=['Yurush','Buraxilish ili', 'Qiymet'],delimiter=',')
print(data.shape)
data.head()
# Out:
# (1328, 3)
#    Buraxilish ili      Yurush     Qiymet
# 0            1999  366 000 km  12500 AZN
# 1            2014  102 000 km    31500 $
# 2            2002  469 700 km  11700 AZN
# 3            1998  556 680 km   9700 AZN
# 4            2000  300 000 km  12700 AZN

# %%
il=data['Buraxilish ili']
yurus=data['Yurush']
qiymet=data['Qiymet']

# %%
plt.scatter(yurus,qiymet,c='r')
plt.title("Yurush-Qiymet")
plt.xlabel("Yurush")
plt.ylabel("Qiymet")
plt.show()

# %%
plt.scatter(il,qiymet,c='r')
plt.title("Buraxilish ili-Qiymet")
plt.xlabel("Buraxilish ili")
plt.ylabel("Qiymet")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x1 = np.random.rand(100)
y1 = np.random.rand(100)
z1 = np.random.rand(100)
ax.scatter(x1,y1,z1,s=20, color='red')

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-1e9fafc124fc> in <module>()
#      23
#      24 #the data from columns a, b and c is ploted.
# ---> 25 ax.scatter(thedata['Buraxilish ili'], thedata['Yurush'], thedata['Qiymet'],color='purple',
#      26             marker='o', s=30)
#      27
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
